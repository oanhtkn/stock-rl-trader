# %%
import gymnasium as gym
from stable_baselines3 import PPO
from app.envs.trading_env import StockTradingEnv
import pandas as pd

# %%
# Load your enriched dataset
df = pd.read_csv("../data/processed/final_dataset.csv")
df = df[df["Ticker"] == "AADR"].reset_index(drop=True)

# %%
# Initialize environment
env = StockTradingEnv(df)

# Wrap environment to make it SB3-compatible
env = gym.wrappers.FlattenObservation(env)

# %%
# Define PPO agent
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    gamma=0.99,
    n_steps=128,
    ent_coef=0.01,
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train agent
model.learn(total_timesteps=20_000)
# Out:
# ----------------------------
# | time/              |     |
# |    fps             | 186 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0029227962 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 3.24e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15e+05     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 2.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 384          |
# | train/                  |              |
# |    approx_kl            | 0.0021574022 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000111     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.61e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0064      |
# |    value_loss           | 1.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0005154805 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000566    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.000675     |
# |    value_loss           | 2.53e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 184           |
# |    iterations           | 5             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 640           |
# | train/                  |               |
# |    approx_kl            | 9.6908305e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0.000294      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.83e+04      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000516     |
# |    value_loss           | 1.4e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 188           |
# |    iterations           | 6             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 1.8429942e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -7.84e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.71e+05      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -3.63e-05     |
# |    value_loss           | 3.5e+05       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 896          |
# | train/                  |              |
# |    approx_kl            | 0.0007142653 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000672     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.25e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 1.74e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 176          |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0018531838 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.000968     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.15e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 9.74e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0048296773 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.09e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 1.17e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 189          |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0017675101 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.000239    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.48e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 7.35e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 195           |
# |    iterations           | 11            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 0.00026429398 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | -0.000271     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.94e+05      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00247      |
# |    value_loss           | 1.14e+06      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.001054734 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -3.39e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 8.08e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 2.03e+04     |
# | time/                   |              |
# |    fps                  | 184          |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0007893564 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000247    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.33e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 6.02e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 2.03e+04     |
# | time/                   |              |
# |    fps                  | 189          |
# |    iterations           | 14           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0010640104 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 3.92e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.87e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00448     |
# |    value_loss           | 1.51e+06     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+03   |
# |    ep_rew_mean          | 2.03e+04   |
# | time/                   |            |
# |    fps                  | 194        |
# |    iterations           | 15         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 1920       |
# | train/                  |            |
# |    approx_kl            | 0.01110043 |
# |    clip_fraction        | 0.0703     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.000452  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.84e+04   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0179    |
# |    value_loss           | 7.44e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 2.03e+04     |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0015349155 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -5.36e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.48e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 5.2e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 2.03e+04      |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 17            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 2176          |
# | train/                  |               |
# |    approx_kl            | 0.00010354258 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 9.42e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.28e+04      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000808     |
# |    value_loss           | 1.16e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 2.03e+04     |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0025733355 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -9.16e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 1.82e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 2.03e+04    |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 19          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.016941259 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.000373    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.63e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 7.54e+04    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 2.03e+04      |
# | time/                   |               |
# |    fps                  | 207           |
# |    iterations           | 20            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 0.00048652384 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | -0.000252     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.43e+05      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 2.86e+05      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+03   |
# |    ep_rew_mean          | 2.03e+04   |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 21         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 2688       |
# | train/                  |            |
# |    approx_kl            | 0.00241951 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | -0.000407  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.26e+04   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00645   |
# |    value_loss           | 9.83e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 2.03e+04     |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 22           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0012687375 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.000336     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000862    |
# |    value_loss           | 2.75e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 2.03e+04      |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 23            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 2944          |
# | train/                  |               |
# |    approx_kl            | 4.1975174e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.000384      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.55e+05      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000297     |
# |    value_loss           | 4.48e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 2.03e+04      |
# | time/                   |               |
# |    fps                  | 213           |
# |    iterations           | 24            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00013550231 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | -0.000178     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.67e+05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 3.16e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1.62e+03       |
# |    ep_rew_mean          | 2.03e+04       |
# | time/                   |                |
# |    fps                  | 216            |
# |    iterations           | 25             |
# |    time_elapsed         | 14             |
# |    total_timesteps      | 3200           |
# | train/                  |                |
# |    approx_kl            | 0.000119370874 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.04          |
# |    explained_variance   | 0.00115        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 9.13e+04       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -0.00134       |
# |    value_loss           | 1.91e+05       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 219           |
# |    iterations           | 26            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 3.3140648e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.000531      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.51e+05      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 6.06e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.25e+04     |
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 27           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 4.647998e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00069     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000665    |
# |    value_loss           | 3.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.25e+04     |
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 28           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0021622502 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000308    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.57e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 8.81e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.25e+04     |
# | time/                   |              |
# |    fps                  | 224          |
# |    iterations           | 29           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 3712         |
# | train/                  |              |
# |    approx_kl            | 0.0006133886 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.00053      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.01e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.00158      |
# |    value_loss           | 1.7e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 226           |
# |    iterations           | 30            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 0.00012346916 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | -0.000767     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 4.4e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 224           |
# |    iterations           | 31            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 3968          |
# | train/                  |               |
# |    approx_kl            | 0.00010091439 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | -0.000155     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.07e+05      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000865     |
# |    value_loss           | 4.41e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.25e+04    |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 32          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.000780351 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 7.29e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.41e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 2.08e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.25e+04     |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 33           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 0.0004582014 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.00109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000688    |
# |    value_loss           | 7.5e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 203           |
# |    iterations           | 34            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 0.00065159705 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.000882      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+04      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.0025       |
# |    value_loss           | 1.1e+05       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.25e+04    |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 35          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 4480        |
# | train/                  |             |
# |    approx_kl            | 0.000339692 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.000414    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52e+05    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 5.25e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.25e+04     |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 36           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0005973228 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | 0.000354     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 5.15e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 204           |
# |    iterations           | 37            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 4736          |
# | train/                  |               |
# |    approx_kl            | 0.00037566433 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.992        |
# |    explained_variance   | 6.25e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.67e+05      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00189      |
# |    value_loss           | 1.09e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 205           |
# |    iterations           | 38            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 4864          |
# | train/                  |               |
# |    approx_kl            | 0.00014243089 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.998        |
# |    explained_variance   | -7.37e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.76e+05      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000776     |
# |    value_loss           | 5.7e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 204           |
# |    iterations           | 39            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 4992          |
# | train/                  |               |
# |    approx_kl            | 8.9934096e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | -0.000262     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.08e+06      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000802     |
# |    value_loss           | 2.12e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.15e+04    |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 40          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.001151762 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.000523    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 3.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.15e+04    |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 41          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.009031697 |
# |    clip_fraction        | 0.00313     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.000636    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 5.4e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.15e+04    |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 42          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.000975735 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.000172    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.23e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 1.46e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 206           |
# |    iterations           | 43            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 5504          |
# | train/                  |               |
# |    approx_kl            | 0.00017881254 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1            |
# |    explained_variance   | -3.34e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.4e+05       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00125      |
# |    value_loss           | 2.85e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 207           |
# |    iterations           | 44            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 0.00025665713 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.999        |
# |    explained_variance   | 0.000795      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.76e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00161      |
# |    value_loss           | 1.57e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.15e+04     |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 45           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 5760         |
# | train/                  |              |
# |    approx_kl            | 0.0025054454 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | -0.000463    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+05     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0046      |
# |    value_loss           | 2.16e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 46            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 5888          |
# | train/                  |               |
# |    approx_kl            | 0.00046239793 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.000403      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.34e+05      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.00433       |
# |    value_loss           | 2.46e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 47            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 6016          |
# | train/                  |               |
# |    approx_kl            | 0.00042892806 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | -0.000248     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.06e+05      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.00131      |
# |    value_loss           | 3.14e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.15e+04      |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 48            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00024138158 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.000163      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.42e+05      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000834     |
# |    value_loss           | 1.37e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.15e+04     |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 49           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 6272         |
# | train/                  |              |
# |    approx_kl            | 0.0010475637 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.000113     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.98e+05     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 9.49e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.15e+04    |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 50          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.001069142 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.000159    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 6.95e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.16e+04      |
# | time/                   |               |
# |    fps                  | 213           |
# |    iterations           | 51            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 6528          |
# | train/                  |               |
# |    approx_kl            | 0.00022097491 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.000389      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.7e+05       |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00017      |
# |    value_loss           | 1.22e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.16e+04      |
# | time/                   |               |
# |    fps                  | 215           |
# |    iterations           | 52            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.4736783e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | -0.000201     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.76e+05      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000165     |
# |    value_loss           | 1.4e+06       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.16e+04     |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 53           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6784         |
# | train/                  |              |
# |    approx_kl            | 0.0002603475 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.000107    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04e+04     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 1.13e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.16e+04     |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 54           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0001333328 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 7.15e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.72e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000596    |
# |    value_loss           | 1.92e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.16e+04      |
# | time/                   |               |
# |    fps                  | 217           |
# |    iterations           | 55            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 7040          |
# | train/                  |               |
# |    approx_kl            | 0.00025924435 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | -6.57e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+05      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.0019       |
# |    value_loss           | 4.53e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.16e+04     |
# ...
# |    approx_kl            | 3.2748096e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.944        |
# |    explained_variance   | 0.000361      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.92e+06      |
# |    n_updates            | 1390          |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 4.53e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 251           |
# |    iterations           | 141           |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 18048         |
# | train/                  |               |
# |    approx_kl            | 0.00019634748 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.932        |
# |    explained_variance   | 0.000182      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+05      |
# |    n_updates            | 1400          |
# |    policy_gradient_loss | -0.00194      |
# |    value_loss           | 4.27e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.77e+04     |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 142          |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 18176        |
# | train/                  |              |
# |    approx_kl            | 0.0045013465 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | -2.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98e+04     |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00862     |
# |    value_loss           | 1.05e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.77e+04    |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 143         |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 18304       |
# | train/                  |             |
# |    approx_kl            | 0.002466679 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.000123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+05    |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00182     |
# |    value_loss           | 3.24e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 253           |
# |    iterations           | 144           |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00018542027 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.957        |
# |    explained_variance   | 0.00017       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.81e+05      |
# |    n_updates            | 1430          |
# |    policy_gradient_loss | -0.000906     |
# |    value_loss           | 7.09e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 253           |
# |    iterations           | 145           |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 18560         |
# | train/                  |               |
# |    approx_kl            | 0.00022123847 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.957        |
# |    explained_variance   | 0.000288      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+05      |
# |    n_updates            | 1440          |
# |    policy_gradient_loss | -0.00193      |
# |    value_loss           | 4.71e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.77e+04    |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 146         |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 18688       |
# | train/                  |             |
# |    approx_kl            | 0.008260576 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 4.99e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75e+05    |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 7.63e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 254           |
# |    iterations           | 147           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 18816         |
# | train/                  |               |
# |    approx_kl            | 0.00047228718 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.931        |
# |    explained_variance   | -0.000423     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.41e+05      |
# |    n_updates            | 1460          |
# |    policy_gradient_loss | -0.00076      |
# |    value_loss           | 1.35e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 254           |
# |    iterations           | 148           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 2.6460271e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.947        |
# |    explained_variance   | 0.000351      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.14e+05      |
# |    n_updates            | 1470          |
# |    policy_gradient_loss | -0.000389     |
# |    value_loss           | 7.37e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 254           |
# |    iterations           | 149           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 19072         |
# | train/                  |               |
# |    approx_kl            | 2.7271919e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.939        |
# |    explained_variance   | -2.98e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.58e+05      |
# |    n_updates            | 1480          |
# |    policy_gradient_loss | -0.000737     |
# |    value_loss           | 1.95e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.77e+04     |
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 150          |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 19200        |
# | train/                  |              |
# |    approx_kl            | 0.0007614563 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | -1.48e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+06     |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 3.5e+06      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.77e+04      |
# | time/                   |               |
# |    fps                  | 254           |
# |    iterations           | 151           |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 19328         |
# | train/                  |               |
# |    approx_kl            | 0.00027286308 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.936        |
# |    explained_variance   | 0.000303      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.58e+06      |
# |    n_updates            | 1500          |
# |    policy_gradient_loss | 3.41e-05      |
# |    value_loss           | 2.45e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 1.88e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 152         |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 3.30857e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | -9.95e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+06    |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | -0.000333   |
# |    value_loss           | 2.39e+06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.88e+04      |
# | time/                   |               |
# |    fps                  | 255           |
# |    iterations           | 153           |
# |    time_elapsed         | 76            |
# |    total_timesteps      | 19584         |
# | train/                  |               |
# |    approx_kl            | 3.3352524e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.943        |
# |    explained_variance   | 0.00022       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.96e+06      |
# |    n_updates            | 1520          |
# |    policy_gradient_loss | -0.000667     |
# |    value_loss           | 3.68e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.88e+04     |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 154          |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 19712        |
# | train/                  |              |
# |    approx_kl            | 6.106496e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | -0.000288    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+05     |
# |    n_updates            | 1530         |
# |    policy_gradient_loss | -0.000566    |
# |    value_loss           | 2.82e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.88e+04      |
# | time/                   |               |
# |    fps                  | 256           |
# |    iterations           | 155           |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 19840         |
# | train/                  |               |
# |    approx_kl            | 0.00031781476 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.909        |
# |    explained_variance   | -9.62e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.05e+05      |
# |    n_updates            | 1540          |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 2.29e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+03      |
# |    ep_rew_mean          | 1.88e+04      |
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 156           |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 5.9839338e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.913        |
# |    explained_variance   | 0.000109      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+05      |
# |    n_updates            | 1550          |
# |    policy_gradient_loss | -0.000705     |
# |    value_loss           | 8.71e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | 1.88e+04     |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 157          |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 20096        |
# | train/                  |              |
# |    approx_kl            | 0.0021244753 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.000122     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28e+05     |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | -0.00567     |
# |    value_loss           | 9.58e+05     |
# ------------------------------------------

# %%
# Save model
model.save("../models/ppo_trading_agent")
print("Model saved to ../models/ppo_trading_agent.zip")
# Out:
# Model saved to ../models/ppo_trading_agent.zip

# %%
#evaluate the trained agent
model = PPO.load("../models/ppo_trading_agent")
obs, _ = env.reset()

for step in range(10):
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()
    if done:
        break
# Out:
# Step: 1, Net Worth: 10000.00, Balance: 10000.00, Shares: 0
# Step: 2, Net Worth: 10000.00, Balance: 15.52, Shares: 183.0
# Step: 3, Net Worth: 10483.12, Balance: 15.52, Shares: 183.0
# Step: 4, Net Worth: 10614.88, Balance: 15.52, Shares: 183.0
# Step: 5, Net Worth: 10671.61, Balance: 15.52, Shares: 183.0
# Step: 6, Net Worth: 10486.78, Balance: 15.52, Shares: 183.0
# Step: 7, Net Worth: 10618.54, Balance: 15.52, Shares: 183.0
# Step: 8, Net Worth: 10247.05, Balance: 15.52, Shares: 183.0
# Step: 9, Net Worth: 10581.94, Balance: 15.52, Shares: 183.0
# Step: 10, Net Worth: 10556.32, Balance: 15.52, Shares: 183.0
